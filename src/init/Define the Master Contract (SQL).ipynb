# %%
# %sql
CREATE OR REPLACE TABLE company_financials_master_def (
    date DATE,
    symbol STRING,
    ingestion_timestamp TIMESTAMP,
    reportedCurrency STRING,
    cik STRING,
    filingDate DATE,
    acceptedDate TIMESTAMP,
    fiscalYear INT,
    period STRING,
    -- Financials
    revenue BIGINT,
    costOfRevenue BIGINT,
    grossProfit BIGINT,
    -- FIX: DECIMAL prevents "3.45" from becoming NULL
    eps DECIMAL(10, 4),
    epsDiluted DECIMAL(10, 4),
    weightedAverageShsOut BIGINT,
    weightedAverageShsOutDil BIGINT
    -- ... add other columns ...
) USING DELTA;
