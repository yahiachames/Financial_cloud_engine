# %%
# %sql
-- 1. Drop the "Snapshot" table you created
DROP TABLE IF EXISTS  serving_layer_ticker_stream
;

# %%
# %sql
-- 1. Create a View (The "Pointer")
-- Note: Use backticks ` ` around the path
CREATE OR REPLACE VIEW gold_layer_ticker_stream AS 
SELECT * FROM delta.`/Volumes/workspace/default/storage/gold/ticker_data_v7`;

# %%
# %sql
-- 1. Create a View (The "Pointer")
-- Note: Use backticks ` ` around the path
CREATE OR REPLACE VIEW serving_layer_ticker_stream AS 
SELECT * FROM delta.`/Volumes/workspace/default/storage/serving/valuation_dashboard_v4`;
