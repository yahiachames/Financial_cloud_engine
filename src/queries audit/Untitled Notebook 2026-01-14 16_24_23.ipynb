# %%
# %sql
SELECT * FROM delta.`/Volumes/workspace/default/storage/gold/ticker_data_v9` -- Use Backticks here
-- WHERE date(window.start) = current_date()

# %%
# %sql
DESCRIBE HISTORY delta.`/Volumes/workspace/default/storage/gold/ticker_data_v9`

# %%
# %sql
SELECT 
    date(window.start) as window_date,
    count(*) as row_count
FROM delta.`/Volumes/workspace/default/storage/gold/ticker_data_v9`
-- GROUP BY history to see the latest batch specifically, if needed
GROUP BY 1

# %%
# %sql
select beta , count(*)  FROM delta.`/Volumes/workspace/default/storage/gold/ticker_data_v9`
group by beta

# %%
# %sql
select * from delta.`/Volumes/workspace/default/storage/silver/ticker_data_v5/`
limit 10

# %%
# %sql
select std(currentPrice) from delta.`/Volumes/workspace/default/storage/silver/ticker_data_v5/`
where date(event_time) = '2026-01-14'
group by s

# %%
# %sql
select s,std(changePercent) from delta.`/Volumes/workspace/default/storage/silver/ticker_data_v5/`
where date(event_time) = '2026-01-14'
group by s
