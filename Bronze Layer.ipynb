# %%
from pyspark.sql import SparkSession

ACCESS_KEY = dbutils.secrets.get(scope = "ticker", key = "access_key")
SECRET_KEY = dbutils.secrets.get(scope = "ticker", key = "secret_key")
SESSION_TOKEN = dbutils.secrets.get(scope = "ticker", key = "session_key")
bucket_name = 'arn:aws:s3:us-east-1:241875596391:accesspoint/accesspoint-to-databricks'


spark = SparkSession.builder \
  .config(
    "fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem"
) \
.config(
    "fs.s3a.aws.credentials.provider",
    "org.apache.hadoop.fs.s3a.TemporaryAWSCredentialsProvider",
) \
.config(
    "fs.s3a.access.key", ACCESS_KEY
) \
.config(
    "fs.s3a.secret.key", SECRET_KEY
) \
.config(
    "fs.s3a.session.token", SESSION_TOKEN
) \
.getOrCreate()

# %%
df = spark.read.option("multiline","true").json("s3://amazon-s3-databricks-medalion-4825/landing/**")
df.show()
